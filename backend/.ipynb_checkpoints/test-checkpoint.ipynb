# %%
import matplotlib.pyplot as plt

# %%
from numpy_tools import get_func_index, get_x_level, sort_2d_array

# %%
from linear_interpolation import linear_interpolation

# %%
points = [[1,2], [3,1], [2,4], [5,5]]

# %%
linear_interpolation?

# %%
a,b=(linear_interpolation(points).T)

# %%
plt.plot(a,b)

# %% [markdown]
# ## Piecewise Sine Curve

# %%
import matplotlib.pyplot as plt

# %%
from numpy_tools import get_func_index, get_x_level, sort_2d_array

# %%
from wavy_interpolation import piecewise_sine_curve, wavy_interpolation
import numpy as np

# %%
points = np.array([[1,2], [3,1], [2,4], [5,5]])

# %%
for clock in range(10):
    a, b=wavy_interpolation(points, clock).T
    plt.plot(a,b)
plt.show()
